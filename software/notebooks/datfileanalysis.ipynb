# %%
# Setup the library
import pyrogue.utilities.fileio as fileio
import numpy as np
import matplotlib.pyplot as plt
import os
from scipy.stats import norm
from scipy.optimize import curve_fit
top_level=f'{os.getcwd()}/..'

# %%
def datfile(filename):
    # Waveforms variables to be filled 
    ampFault = { i : []  for i in range(4) }  
    xPosFault = []
    yPosFault = []
    qBunchFault = []
    
    # Open the .dat file
    with fileio.FileReader(files=f'{top_level}/datfile/'+filename) as fd:
        
        # Loop through the file data
        for header,data in fd.records():
    
            # Check for error in frame
            if (header.error>0):
                # Look at record header data
                print(f"Processing record. Total={fd.totCount}, Current={fd.currCount}")
                print(f"Record size    = {header.size}")
                print(f"Record channel = {header.channel}")
                print(f"Record flags   = {header.flags:#x}")
                print(f"Record error   = {header.error:#x}")
    
            # Check if AMP Fault waveform
            elif (header.channel < 16) and (header.channel >= 12):
                ampFault[header.channel-12].append(data[:].view(np.int16))
    
            # Check if AMP Live waveform
            elif header.channel == 24:
                fpData = data[:].view(np.float32)
                fpDataLen = len(fpData)
                xPosFault.append(   fpData[0:(fpDataLen*3)+0:3] ) 
                yPosFault.append(   fpData[1:(fpDataLen*3)+1:3] )
                qBunchFault.append( fpData[2:(fpDataLen*3)+2:3] )
            
            # Else undefined stream index
            else:
                print( f'UNDEFINED DATA STREAM[{header.channel}]!!!')

    return ampFault

# %% [markdown]
# # 2024/1/31 110828

# %%
ampFault=datfile("data_20240131_145745.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[1][0])
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
#plt.xlim()
plt.grid()

# %%
start=3020
stop=start+30
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[1][0][start:stop])
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.grid()

# %% [markdown]
# # 2024/1/31 151137

# %%
ampFault=datfile("data_20240131_151137.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[0][0])
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
#plt.xlim()
plt.grid()

# %%
start=40820
stop=start+40
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[0][0][start:stop])
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.grid()

# %% [markdown]
# # 2024/1/31 153025

# %%
ampFault=datfile("data_20240131_153025.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[0][0])
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
#plt.xlim()
plt.grid()

# %%
start=26760
stop=start+40
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[0][0][start:stop])
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.grid()

# %% [markdown]
# # 2024/1/31 154616

# %%
ampFault=datfile("data_20240131_154616.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[0][0])
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
#plt.xlim()
plt.grid()

# %%
start=31420
stop=start+40
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[0][0][start:stop],label="Ch0")
plt.plot(timeSteps[start:stop],ampFault[1][0][start:stop],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
plt.grid()

# %% [markdown]
# # 2024/1/31 160857

# %%
ampFault=datfile("data_20240131_160857.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[0][0])
plt.plot(timeSteps,ampFault[1][0])
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
#plt.xlim()
plt.grid()

# %%
start=40060
stop=start+40
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[0][0][start:stop],label="Ch0")
plt.plot(timeSteps[start:stop],ampFault[1][0][start:stop],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
plt.grid()

# %% [markdown]
# # 2024/1/31 173932

# %%
ampFault=datfile("data_20240131_173932.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[2][0])
plt.plot(timeSteps,ampFault[3][0])
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
#plt.xlim()
plt.grid()

# %%
start=6730
stop=start+40
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[2][0][start:stop],label="Ch2")
plt.plot(timeSteps[start:stop],ampFault[3][0][start:stop],label="Ch3")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
plt.grid()

# %% [markdown]
# # 2024/1/31 174357

# %%
ampFault=datfile("data_20240131_174357.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[2][0])
plt.plot(timeSteps,ampFault[3][0])
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
#plt.xlim()
plt.grid()

# %%
start=17230
stop=start+40
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[2][0][start:stop],label="Ch2")
plt.plot(timeSteps[start:stop],ampFault[3][0][start:stop],label="Ch3")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
plt.grid()

# %% [markdown]
# # 2024/2/1 132735

# %%
ampFault=datfile("data_20240201_132735.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[0][0])
#plt.plot(timeSteps,ampFault[1][0])
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
#plt.xlim()
plt.grid()

# %%
start=100
stop=start+40
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[0][0][start:stop],label="Ch0")
#plt.plot(timeSteps[start:stop],ampFault[1][0][start:stop],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
plt.grid()

# %% [markdown]
# # 2024/2/1 140343

# %%
ampFault=datfile("data_20240201_140343.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[0][0])
plt.plot(timeSteps,ampFault[1][0])
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
#plt.xlim()
plt.grid()

# %%
start=140
stop=start+60
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[0][0][start:stop],label="Ch0")
plt.plot(timeSteps[start:stop],ampFault[1][0][start:stop],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
plt.grid()

# %% [markdown]
# # 2024/2/1 140407

# %%
ampFault=datfile("data_20240201_140407.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[0][0])
plt.plot(timeSteps,ampFault[1][0])
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
#plt.xlim()
plt.grid()

# %%
start=160
stop=start+60
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[0][0][start:stop],label="Ch0")
plt.plot(timeSteps[start:stop],ampFault[1][0][start:stop],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
plt.grid()

# %% [markdown]
# # 2024/2/1 164734

# %%
ampFault=datfile("data_20240201_164734.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[0][0],label="Ch0")
plt.plot(timeSteps,ampFault[1][0],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
#plt.xlim()
plt.legend()
plt.grid()

# %%
start=3683
stop=start+30
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[0][0][start:stop],label="Ch0")
plt.plot(timeSteps[start:stop],ampFault[1][0][start:stop],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
plt.grid()

# %% [markdown]
# # 2024/2/1 165216

# %%
ampFault=datfile("data_20240201_165216.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[2][0],label="Ch2")
plt.plot(timeSteps,ampFault[3][0],label="Ch3")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
#plt.xlim()
plt.legend()
plt.grid()

# %%
start=33060
stop=start+30
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[2][0][start:stop],label="Ch2")
plt.plot(timeSteps[start:stop],ampFault[3][0][start:stop],label="Ch3")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
plt.grid()

# %% [markdown]
# # 2024/2/1 170816

# %%
ampFault=datfile("data_20240201_170816.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[0][0],label="Ch0")
plt.plot(timeSteps,ampFault[1][0],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
#plt.xlim()
plt.legend()
plt.grid()

# %%
start=32710
stop=start+50
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[0][0][start:stop],label="Ch0")
plt.plot(timeSteps[start:stop],ampFault[1][0][start:stop],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
plt.grid()

# %% [markdown]
# # 2024/2/1 170931

# %%
ampFault=datfile("data_20240201_170931.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[0][0],label="Ch0")
plt.plot(timeSteps,ampFault[1][0],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
#plt.xlim()
plt.legend()
plt.grid()

# %%
start=3800
stop=start+50
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[0][0][start:stop],label="Ch0")
plt.plot(timeSteps[start:stop],ampFault[1][0][start:stop],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
plt.grid()

# %% [markdown]
# # 2024/2/1 171617

# %%
ampFault=datfile("data_20240201_171617.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[2][0],label="Ch2")
plt.plot(timeSteps,ampFault[3][0],label="Ch3")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
#plt.xlim()
plt.legend()
plt.grid()

# %%
start=31250
stop=start+40
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[2][0][start:stop],label="Ch2")
plt.plot(timeSteps[start:stop],ampFault[3][0][start:stop],label="Ch3")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
plt.grid()

# %% [markdown]
# # 2024/2/1 171821

# %%
ampFault=datfile("data_20240201_171821.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[2][0],label="Ch2")
plt.plot(timeSteps,ampFault[3][0],label="Ch3")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
#plt.xlim()
plt.legend()
plt.grid()

# %%
start=27840
stop=start+50
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[2][0][start:stop],label="Ch2")
plt.plot(timeSteps[start:stop],ampFault[3][0][start:stop],label="Ch3")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
plt.grid()

# %% [markdown]
# # 2024/2/1 171901

# %%
ampFault=datfile("data_20240201_171901.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[2][0],label="Ch2")
plt.plot(timeSteps,ampFault[3][0],label="Ch3")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
#plt.xlim()
plt.legend()
plt.grid()

# %%
start=17025
stop=start+50
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[2][0][start:stop],label="Ch2")
plt.plot(timeSteps[start:stop],ampFault[3][0][start:stop],label="Ch3")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
plt.grid()

# %% [markdown]
# # 2024/2/1 172055

# %%
ampFault=datfile("data_20240201_172055.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[2][0],label="Ch2")
plt.plot(timeSteps,ampFault[3][0],label="Ch3")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
#plt.xlim()
plt.legend()
plt.grid()

# %%
start=17875
stop=start+50
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[2][0][start:stop],label="Ch2")
plt.plot(timeSteps[start:stop],ampFault[3][0][start:stop],label="Ch3")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
plt.grid()

# %% [markdown]
# # 2024/2/1 172637

# %%
ampFault=datfile("data_20240201_172637.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[0][0],label="Ch0")
plt.plot(timeSteps,ampFault[1][0],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
#plt.xlim()
plt.legend()
plt.grid()

# %%
start=10375
stop=start+50
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[0][0][start:stop],label="Ch0")
plt.plot(timeSteps[start:stop],ampFault[1][0][start:stop],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
plt.grid()

# %% [markdown]
# # 2024/2/1 173303

# %%
ampFault=datfile("data_20240201_173303.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[2][0],label="Ch2")
plt.plot(timeSteps,ampFault[3][0],label="Ch3")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
#plt.xlim()
plt.legend()
plt.grid()

# %%
start=4795
stop=start+50
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[2][0][start:stop],label="Ch2")
plt.plot(timeSteps[start:stop],ampFault[3][0][start:stop],label="Ch3")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
plt.grid()

# %% [markdown]
# # 2024/2/1 215847

# %%
ampFault=datfile("data_20240201_215847.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[0][0],label="Ch0")
plt.plot(timeSteps,ampFault[1][0],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
#plt.xlim()
plt.legend()
plt.grid()

# %%
start=69000
stop=start+50
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[0][0][start:stop],label="Ch0")
plt.plot(timeSteps[start:stop],ampFault[1][0][start:stop],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
plt.grid()

# %% [markdown]
# # 2024/2/2 154417

# %%
ampFault=datfile("data_20240202_154417.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[0][0],label="Ch0")
plt.plot(timeSteps,ampFault[1][0],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.xlim(6000,8000)
plt.legend()
plt.grid()

# %%
start=17782+16*80
stop=start+16*15
plt.figure(figsize=(14,5))
plt.plot(timeSteps[start:stop],ampFault[0][0][start:stop],label="Ch0")
plt.plot(timeSteps[start:stop],ampFault[1][0][start:stop],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
plt.grid()

# %%
bunch=0
bunchfill=[]
for i in range(5120):
    if ampFault[0][0][17782+8*i]>300:
        bunch+=1
        bunchfill.append(i)

print(bunch)
# Out:
# 1591

# %%
indices_0=[]
indices_1=[]
for i in bunchfill:
    indices_0.append(17782+8*i)
    indices_1.append(17783+8*i)

# %%
plt.figure(figsize=(14,5))
plt.scatter(timeSteps[indices_0],ampFault[0][0][indices_0],label="Sum")
plt.scatter(timeSteps[indices_0],ampFault[1][0][indices_1],label="Delta")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
#plt.xlim(4350,5000)
plt.grid()

# %%
np.average(ampFault[0][0][indices_0])
# Out:
# 1849.9258328095536

# %% [markdown]
# # 2024/2/3 194640

# %%
ampFault=datfile("data_20240203_194640.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[0][0],label="Ch0")
plt.plot(timeSteps,ampFault[1][0],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.xlim(5000,6000)
plt.legend()
plt.grid()

# %%
start=2694
stop=start+16*5
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[0][0][start:stop],label="Ch0")
plt.plot(timeSteps[start:stop],ampFault[1][0][start:stop],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
plt.grid()

# %%
indices_0=[]
indices_1=[]
for i in range(2560):
    indices_0.append(2694+16*i)
    indices_1.append(2694+16*i)

# %%
plt.figure(figsize=(9,5))
plt.scatter(timeSteps[indices_0],ampFault[0][0][indices_0],label="Ch0")
#plt.plot(timeSteps[indices_0],ampFault[1][0][indices_1],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
plt.xlim(2000,3000)
plt.grid()

# %% [markdown]
# # 2024/2/8 211853

# %%
ampFault=datfile("data_20240208_211853.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[0][0],label="Ch0")
plt.plot(timeSteps,ampFault[1][0],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
#plt.xlim(5000,6000)
plt.legend()
plt.grid()

# %%
start=30700
stop=start+200
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[0][0][start:stop],label="Ch0")
plt.plot(timeSteps[start:stop],ampFault[1][0][start:stop],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
plt.grid()

# %% [markdown]
# # 2024/2/8 235615

# %%
ampFault=datfile("data_20240208_235615.dat")

size = len(ampFault[0][0])

timeBin = 1.0/(0.509*8.0) # Unit of ns for 4.072 GSPS
timeSteps = np.linspace(0, timeBin*(size-1), num=size)

# Plot the Waveform Full Scale
plt.figure(figsize=(14,5))
plt.plot(timeSteps,ampFault[0][0],label="Ch0")
plt.plot(timeSteps,ampFault[1][0],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
#plt.xlim(5000,6000)
plt.legend()
plt.grid()

# %%
start=18020
stop=start+150
plt.figure(figsize=(9,5))
plt.plot(timeSteps[start:stop],ampFault[0][0][start:stop],label="Ch0")
plt.plot(timeSteps[start:stop],ampFault[1][0][start:stop],label="Ch1")
plt.xlabel("Time (ns)")
plt.ylabel("Counts")
plt.legend()
plt.grid()
